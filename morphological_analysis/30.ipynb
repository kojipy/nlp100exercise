# %% [markdown]
# # 30. 形態素解析結果の読み込みPermalink
# 形態素解析結果（neko.txt.mecab）を読み込むプログラムを実装せよ．ただし，各形態素は表層形（surface），基本形（base），品詞（pos），品詞細分類1（pos1）をキーとするマッピング型に格納し，1文を形態素（マッピング型）のリストとして表現せよ．第4章の残りの問題では，ここで作ったプログラムを活用せよ．

# %%
def parse_mecab(block):
    res = []
    for line in block.split('\n'):
        if line == '':
            return res
        (surface, attr) = line.split('\t')
        attr = attr.split(',')
        lineDict = {
            'surface': surface,
            'base': attr[6],
            'pos': attr[0],
            'pos1': attr[1]
        }
        res.append(lineDict)

# %%
# mecab_text = "./neko.txt"
filename = r"C:\Users\sakamaki\git\nlp100exercise\morphological_analysis\neko.txt.mecab"

with open(filename, mode='rt', encoding='utf-8') as f:
    blocks = f.read().split('EOS\n')

blocks = list(filter(lambda x: x != '', blocks))
blocks = [parse_mecab(block) for block in blocks]
print(blocks[5])
# Out:
# [{'surface': '吾輩', 'base': '吾輩', 'pos': '名詞', 'pos1': '代名詞'}, {'surface': 'は', 'base': 'は', 'pos': '助詞', 'pos1': '係助詞'}, {'surface': 'ここ', 'base': 'ここ', 'pos': '名詞', 'pos1': '代名詞'}, {'surface': 'で', 'base': 'で', 'pos': '助詞', 'pos1': '格助詞'}, {'surface': '始め', 'base': '始める', 'pos': '動詞', 'pos1': '自立'}, {'surface': 'て', 'base': 'て', 'pos': '助詞', 'pos1': '接続助詞'}, {'surface': '人間', 'base': '人間', 'pos': '名詞', 'pos1': '一般'}, {'surface': 'という', 'base': 'という', 'pos': '助詞', 'pos1': '格助詞'}, {'surface': 'もの', 'base': 'もの', 'pos': '名詞', 'pos1': '非自立'}, {'surface': 'を', 'base': 'を', 'pos': '助詞', 'pos1': '格助詞'}, {'surface': '見', 'base': '見る', 'pos': '動詞', 'pos1': '自立'}, {'surface': 'た', 'base': 'た', 'pos': '助動詞', 'pos1': '*'}, {'surface': '。', 'base': '。', 'pos': '記号', 'pos1': '句点'}]

# %%
blocks
# Out:
#   {'surface': 'と', 'base': 'と', 'pos': '助詞', 'pos1': '格助詞'},
#   {'surface': '予', 'base': '*', 'pos': '名詞', 'pos1': '一般'},
#   {'surface': 'じ', 'base': 'じ', 'pos': '助動詞', 'pos1': '*'},
#   {'surface': 'め', 'base': 'め', 'pos': '名詞', 'pos1': '一般'},
#   {'surface': '念', 'base': '念', 'pos': '名詞', 'pos1': '一般'},
#   {'surface': 'を', 'base': 'を', 'pos': '助詞', 'pos1': '格助詞'},
#   {'surface': '押し', 'base': '押す', 'pos': '動詞', 'pos1': '自立'},
#   {'surface': 'て', 'base': 'て', 'pos': '助詞', 'pos1': '接続助詞'},
#   {'surface': 'また', 'base': 'また', 'pos': '接続詞', 'pos1': '*'},
#   {'surface': '読み', 'base': '読む', 'pos': '動詞', 'pos1': '自立'},
#   {'surface': '始める', 'base': '始める', 'pos': '動詞', 'pos1': '非自立'},
#   {'surface': '。', 'base': '。', 'pos': '記号', 'pos1': '句点'}],
#  [{'surface': 'ケート', 'base': '*', 'pos': '名詞', 'pos1': '一般'},
#   {'surface': 'は', 'base': 'は', 'pos': '助詞', 'pos1': '係助詞'},
#   {'surface': '窓', 'base': '窓', 'pos': '名詞', 'pos1': '一般'},
#   {'surface': 'から', 'base': 'から', 'pos': '助詞', 'pos1': '格助詞'},
#   {'surface': '外面', 'base': '外面', 'pos': '名詞', 'pos1': '一般'},
#   {'surface': 'を', 'base': 'を', 'pos': '助詞', 'pos1': '格助詞'},
#   {'surface': '眺める', 'base': '眺める', 'pos': '動詞', 'pos1': '自立'},
#   {'surface': '。', 'base': '。', 'pos': '記号', 'pos1': '句点'}],
#  [{'surface': '小児', 'base': '小児', 'pos': '名詞', 'pos1': '一般'},
#   {'surface': 'が', 'base': 'が', 'pos': '助詞', 'pos1': '格助詞'},
#   {'surface': '球', 'base': '球', 'pos': '名詞', 'pos1': '一般'},
#   {'surface': 'を', 'base': 'を', 'pos': '助詞', 'pos1': '格助詞'},
#   {'surface': '投げ', 'base': '投げる', 'pos': '動詞', 'pos1': '自立'},
#   {'surface': 'て', 'base': 'て', 'pos': '助詞', 'pos1': '接続助詞'},
#   {'surface': '遊ん', 'base': '遊ぶ', 'pos': '動詞', 'pos1': '自立'},
#   {'surface': 'で', 'base': 'で', 'pos': '助詞', 'pos1': '接続助詞'},
#   {'surface': 'いる', 'base': 'いる', 'pos': '動詞', 'pos1': '非自立'},
#   {'surface': '。', 'base': '。', 'pos': '記号', 'pos1': '句点'}],
#  [{'surface': '彼等', 'base': '彼等', 'pos': '名詞', 'pos1': '代名詞'},
#   {'surface': 'は', 'base': 'は', 'pos': '助詞', 'pos1': '係助詞'},
#   {'surface': '高く', 'base': '高い', 'pos': '形容詞', 'pos1': '自立'},
#   {'surface': '球', 'base': '球', 'pos': '名詞', 'pos1': '一般'},
#   {'surface': 'を', 'base': 'を', 'pos': '助詞', 'pos1': '格助詞'},
#   {'surface': '空中', 'base': '空中', 'pos': '名詞', 'pos1': '一般'},
#   {'surface': 'に', 'base': 'に', 'pos': '助詞', 'pos1': '格助詞'},
#   {'surface': '擲つ', 'base': '擲つ', 'pos': '動詞', 'pos1': '自立'},
#   {'surface': '。', 'base': '。', 'pos': '記号', 'pos1': '句点'}],
#  [{'surface': '球', 'base': '球', 'pos': '名詞', 'pos1': '一般'},
#   {'surface': 'は', 'base': 'は', 'pos': '助詞', 'pos1': '係助詞'},
#   {'surface': '上', 'base': '上', 'pos': '名詞', 'pos1': '一般'},
#   {'surface': 'へ', 'base': 'へ', 'pos': '助詞', 'pos1': '格助詞'},
#   {'surface': '上', 'base': '上', 'pos': '名詞', 'pos1': '一般'},
#   {'surface': 'へ', 'base': 'へ', 'pos': '助詞', 'pos1': '格助詞'},
#   {'surface': 'と', 'base': 'と', 'pos': '助詞', 'pos1': '格助詞'},
#   {'surface': 'のぼる', 'base': 'のぼる', 'pos': '動詞', 'pos1': '自立'},
#   {'surface': '。', 'base': '。', 'pos': '記号', 'pos1': '句点'}],
#  [{'surface': 'しばらく', 'base': 'しばらく', 'pos': '副詞', 'pos1': '助詞類接続'},
#   {'surface': 'する', 'base': 'する', 'pos': '動詞', 'pos1': '自立'},
#   {'surface': 'と', 'base': 'と', 'pos': '助詞', 'pos1': '格助詞'},
#   {'surface': '落ち', 'base': '落ちる', 'pos': '動詞', 'pos1': '自立'},
#   {'surface': 'て', 'base': 'て', 'pos': '助詞', 'pos1': '接続助詞'},
#   {'surface': '来る', 'base': '来る', 'pos': '動詞', 'pos1': '非自立'},
#   {'surface': '。', 'base': '。', 'pos': '記号', 'pos1': '句点'}],
#  [{'surface': '彼等', 'base': '彼等', 'pos': '名詞', 'pos1': '代名詞'},
#   {'surface': 'は', 'base': 'は', 'pos': '助詞', 'pos1': '係助詞'},
#   {'surface': 'また', 'base': 'また', 'pos': '接続詞', 'pos1': '*'},
#   {'surface': '球', 'base': '球', 'pos': '名詞', 'pos1': '一般'},
#   {'surface': 'を', 'base': 'を', 'pos': '助詞', 'pos1': '格助詞'},
#   {'surface': '高く', 'base': '高い', 'pos': '形容詞', 'pos1': '自立'},
#   {'surface': '擲つ', 'base': '擲つ', 'pos': '動詞', 'pos1': '自立'},
#   {'surface': '。', 'base': '。', 'pos': '記号', 'pos1': '句点'}],
#  [{'surface': '再び', 'base': '再び', 'pos': '副詞', 'pos1': '助詞類接続'},
#   {'surface': '三', 'base': '三', 'pos': '名詞', 'pos1': '数'},
#   {'surface': '度', 'base': '度', 'pos': '名詞', 'pos1': '接尾'},
#   {'surface': '。', 'base': '。', 'pos': '記号', 'pos1': '句点'}],
#  [{'surface': '擲つ', 'base': '擲つ', 'pos': '動詞', 'pos1': '自立'},
#   {'surface': 'たび', 'base': 'たび', 'pos': '名詞', 'pos1': '非自立'},
#   {'surface': 'に', 'base': 'に', 'pos': '助詞', 'pos1': '格助詞'},
#   {'surface': '球', 'base': '球', 'pos': '名詞', 'pos1': '一般'},
#   {'surface': 'は', 'base': 'は', 'pos': '助詞', 'pos1': '係助詞'},
#   {'surface': '落ち', 'base': '落ちる', 'pos': '動詞', 'pos1': '自立'},
#   {'surface': 'て', 'base': 'て', 'pos': '助詞', 'pos1': '接続助詞'},
#   {'surface': 'くる', 'base': 'くる', 'pos': '動詞', 'pos1': '非自立'},
#   {'surface': '。', 'base': '。', 'pos': '記号', 'pos1': '句点'}],
#  [{'surface': 'なぜ', 'base': 'なぜ', 'pos': '副詞', 'pos1': '助詞類接続'},
#   {'surface': '落ちる', 'base': '落ちる', 'pos': '動詞', 'pos1': '自立'},
#   {'surface': 'の', 'base': 'の', 'pos': '名詞', 'pos1': '非自立'},
#   {'surface': 'か', 'base': 'か', 'pos': '助詞', 'pos1': '副助詞／並立助詞／終助詞'},
#   {'surface': '、', 'base': '、', 'pos': '記号', 'pos1': '読点'},
#   {'surface': 'なぜ', 'base': 'なぜ', 'pos': '副詞', 'pos1': '助詞類接続'},
#   {'surface': '上', 'base': '上', 'pos': '名詞', 'pos1': '一般'},
#   {'surface': 'へ', 'base': 'へ', 'pos': '助詞', 'pos1': '格助詞'},
#   {'surface': '上', 'base': '上', 'pos': '名詞', 'pos1': '一般'},
#   {'surface': 'へ', 'base': 'へ', 'pos': '助詞', 'pos1': '格助詞'},
#   {'surface': 'と', 'base': 'と', 'pos': '助詞', 'pos1': '格助詞'},
#   {'surface': 'のみ', 'base': 'のみ', 'pos': '助詞', 'pos1': '副助詞'},
#   {'surface': 'のぼら', 'base': 'のぼる', 'pos': '動詞', 'pos1': '自立'},
#   {'surface': 'ぬ', 'base': 'ぬ', 'pos': '助動詞', 'pos1': '*'},
#   {'surface': 'か', 'base': 'か', 'pos': '助詞', 'pos1': '副助詞／並立助詞／終助詞'},
#   {'surface': 'と', 'base': 'と', 'pos': '助詞', 'pos1': '格助詞'},
#   {'surface': 'ケート', 'base': '*', 'pos': '名詞', 'pos1': '一般'},
#   {'surface': 'が', 'base': 'が', 'pos': '助詞', 'pos1': '格助詞'},
#   {'surface': '聞く', 'base': '聞く', 'pos': '動詞', 'pos1': '自立'},
#   {'surface': '。', 'base': '。', 'pos': '記号', 'pos1': '句点'}],
#  [{'surface': '「', 'base': '「', 'pos': '記号', 'pos1': '括弧開'},
#   {'surface': '巨人', 'base': '巨人', 'pos': '名詞', 'pos1': '固有名詞'},
#   {'surface': 'が', 'base': 'が', 'pos': '助詞', 'pos1': '格助詞'},
#   {'surface': '地中', 'base': '地中', 'pos': '名詞', 'pos1': '一般'},
#   {'surface': 'に', 'base': 'に', 'pos': '助詞', 'pos1': '格助詞'},
#   {'surface': '住む', 'base': '住む', 'pos': '動詞', 'pos1': '自立'},
#   {'surface': '故', 'base': '故', 'pos': '名詞', 'pos1': '非自立'},
#   {'surface': 'に', 'base': 'に', 'pos': '助詞', 'pos1': '格助詞'},
#   {'surface': '」', 'base': '」', 'pos': '記号', 'pos1': '括弧閉'},
#   {'surface': 'と', 'base': 'と', 'pos': '助詞', 'pos1': '格助詞'},
#   {'surface': '母', 'base': '母', 'pos': '名詞', 'pos1': '一般'},
#   {'surface': 'が', 'base': 'が', 'pos': '助詞', 'pos1': '格助詞'},
#   {'surface': '答える', 'base': '答える', 'pos': '動詞', 'pos1': '自立'},
#   {'surface': '。', 'base': '。', 'pos': '記号', 'pos1': '句点'}],
#  [{'surface': '「', 'base': '「', 'pos': '記号', 'pos1': '括弧開'},
#   {'surface': '彼', 'base': '彼', 'pos': '名詞', 'pos1': '代名詞'},
#   {'surface': 'は', 'base': 'は', 'pos': '助詞', 'pos1': '係助詞'},
#   {'surface': '巨人', 'base': '巨人', 'pos': '名詞', 'pos1': '固有名詞'},
#   {'surface': '引力', 'base': '引力', 'pos': '名詞', 'pos1': '一般'},
#   {'surface': 'で', 'base': 'だ', 'pos': '助動詞', 'pos1': '*'},
#   {'surface': 'ある', 'base': 'ある', 'pos': '助動詞', 'pos1': '*'},
#   {'surface': '。', 'base': '。', 'pos': '記号', 'pos1': '句点'}],
#  [{'surface': '彼', 'base': '彼', 'pos': '名詞', 'pos1': '代名詞'},
#   {'surface': 'は', 'base': 'は', 'pos': '助詞', 'pos1': '係助詞'},
#   {'surface': '強い', 'base': '強い', 'pos': '形容詞', 'pos1': '自立'},
#   {'surface': '。', 'base': '。', 'pos': '記号', 'pos1': '句点'}],
#  [{'surface': '彼', 'base': '彼', 'pos': '名詞', 'pos1': '代名詞'},
#   {'surface': 'は', 'base': 'は', 'pos': '助詞', 'pos1': '係助詞'},
#   {'surface': '万物', 'base': '万物', 'pos': '名詞', 'pos1': '一般'},
#   {'surface': 'を', 'base': 'を', 'pos': '助詞', 'pos1': '格助詞'},
#   {'surface': '己', 'base': '己', 'pos': '名詞', 'pos1': '代名詞'},
#   {'surface': 'れ', 'base': 'る', 'pos': '助動詞', 'pos1': '*'},
#   {'surface': 'の', 'base': 'の', 'pos': '助詞', 'pos1': '連体化'},
#   {'surface': '方', 'base': '方', 'pos': '名詞', 'pos1': '非自立'},
#   {'surface': 'へ', 'base': 'へ', 'pos': '助詞', 'pos1': '格助詞'},
#   {'surface': 'と', 'base': 'と', 'pos': '助詞', 'pos1': '格助詞'},
#   {'surface': '引く', 'base': '引く', 'pos': '動詞', 'pos1': '自立'},
#   {'surface': '。', 'base': '。', 'pos': '記号', 'pos1': '句点'}],
#  [{'surface': '彼', 'base': '彼', 'pos': '名詞', 'pos1': '代名詞'},
#   {'surface': 'は', 'base': 'は', 'pos': '助詞', 'pos1': '係助詞'},
#   {'surface': '家屋', 'base': '家屋', 'pos': '名詞', 'pos1': '一般'},
#   {'surface': 'を', 'base': 'を', 'pos': '助詞', 'pos1': '格助詞'},
#   {'surface': '地上', 'base': '地上', 'pos': '名詞', 'pos1': '一般'},
#   {'surface': 'に', 'base': 'に', 'pos': '助詞', 'pos1': '格助詞'},
#   {'surface': '引く', 'base': '引く', 'pos': '動詞', 'pos1': '自立'},
#   {'surface': '。', 'base': '。', 'pos': '記号', 'pos1': '句点'}],
#  [{'surface': '引か', 'base': '引く', 'pos': '動詞', 'pos1': '自立'},
#   {'surface': 'ね', 'base': 'ぬ', 'pos': '助動詞', 'pos1': '*'},
#   {'surface': 'ば', 'base': 'ば', 'pos': '助詞', 'pos1': '接続助詞'},
#   {'surface': '飛ん', 'base': '飛ぶ', 'pos': '動詞', 'pos1': '自立'},
#   {'surface': 'で', 'base': 'で', 'pos': '助詞', 'pos1': '接続助詞'},
#   {'surface': 'しまう', 'base': 'しまう', 'pos': '動詞', 'pos1': '非自立'},
#   {'surface': '。', 'base': '。', 'pos': '記号', 'pos1': '句点'}],
#  [{'surface': '小児', 'base': '小児', 'pos': '名詞', 'pos1': '一般'},
#   {'surface': 'も', 'base': 'も', 'pos': '助詞', 'pos1': '係助詞'},
#   {'surface': '飛ん', 'base': '飛ぶ', 'pos': '動詞', 'pos1': '自立'},
#   {'surface': 'で', 'base': 'で', 'pos': '助詞', 'pos1': '接続助詞'},
#   {'surface': 'しまう', 'base': 'しまう', 'pos': '動詞', 'pos1': '非自立'},
#   {'surface': '。', 'base': '。', 'pos': '記号', 'pos1': '句点'}],
#  [{'surface': '葉', 'base': '葉', 'pos': '名詞', 'pos1': '一般'},
#   {'surface': 'が', 'base': 'が', 'pos': '助詞', 'pos1': '格助詞'},
#   {'surface': '落ちる', 'base': '落ちる', 'pos': '動詞', 'pos1': '自立'},
#   {'surface': 'の', 'base': 'の', 'pos': '名詞', 'pos1': '非自立'},
#   {'surface': 'を', 'base': 'を', 'pos': '助詞', 'pos1': '格助詞'},
#   {'surface': '見', 'base': '見る', 'pos': '動詞', 'pos1': '自立'},
#   {'surface': 'たろ', 'base': 'た', 'pos': '助動詞', 'pos1': '*'},
#   {'surface': 'う', 'base': 'う', 'pos': '助動詞', 'pos1': '*'},
#   {'surface': '。', 'base': '。', 'pos': '記号', 'pos1': '句点'}],
#  [{'surface': 'あれ', 'base': 'あれ', 'pos': '名詞', 'pos1': '代名詞'},
#   {'surface': 'は', 'base': 'は', 'pos': '助詞', 'pos1': '係助詞'},
#   {'surface': '巨人', 'base': '巨人', 'pos': '名詞', 'pos1': '固有名詞'},
#   {'surface': '引力', 'base': '引力', 'pos': '名詞', 'pos1': '一般'},
#   {'surface': 'が', 'base': 'が', 'pos': '助詞', 'pos1': '格助詞'},
#   {'surface': '呼ぶ', 'base': '呼ぶ', 'pos': '動詞', 'pos1': '自立'},
#   {'surface': 'の', 'base': 'の', 'pos': '名詞', 'pos1': '非自立'},
#   {'surface': 'で', 'base': 'だ', 'pos': '助動詞', 'pos1': '*'},
#   {'surface': 'ある', 'base': 'ある', 'pos': '助動詞', 'pos1': '*'},
#   {'surface': '。', 'base': '。', 'pos': '記号', 'pos1': '句点'}],
#  [{'surface': '本', 'base': '本', 'pos': '名詞', 'pos1': '一般'},
#   {'surface': 'を', 'base': 'を', 'pos': '助詞', 'pos1': '格助詞'},
#   {'surface': '落す', 'base': '落す', 'pos': '動詞', 'pos1': '自立'},
#   {'surface': '事', 'base': '事', 'pos': '名詞', 'pos1': '非自立'},
#   {'surface': 'が', 'base': 'が', 'pos': '助詞', 'pos1': '格助詞'},
#   {'surface': 'あろ', 'base': 'ある', 'pos': '動詞', 'pos1': '自立'},
#   {'surface': 'う', 'base': 'う', 'pos': '助動詞', 'pos1': '*'},
#   {'surface': '。', 'base': '。', 'pos': '記号', 'pos1': '句点'}],
#  [{'surface': '巨人', 'base': '巨人', 'pos': '名詞', 'pos1': '固有名詞'},
#   {'surface': '引力', 'base': '引力', 'pos': '名詞', 'pos1': '一般'},
#   {'surface': 'が', 'base': 'が', 'pos': '助詞', 'pos1': '格助詞'},
#   {'surface': '来い', 'base': '来る', 'pos': '動詞', 'pos1': '自立'},
#   {'surface': 'と', 'base': 'と', 'pos': '助詞', 'pos1': '格助詞'},
#   {'surface': 'いう', 'base': 'いう', 'pos': '動詞', 'pos1': '自立'},
#   {'surface': 'から', 'base': 'から', 'pos': '助詞', 'pos1': '接続助詞'},
#   {'surface': 'で', 'base': 'だ', 'pos': '助動詞', 'pos1': '*'},
#   {'surface': 'ある', 'base': 'ある', 'pos': '助動詞', 'pos1': '*'},
#   {'surface': '。', 'base': '。', 'pos': '記号', 'pos1': '句点'}],
#  [{'surface': '球', 'base': '球', 'pos': '名詞', 'pos1': '一般'},
#   {'surface': 'が', 'base': 'が', 'pos': '助詞', 'pos1': '格助詞'},
#   {'surface': '空', 'base': '空', 'pos': '名詞', 'pos1': '一般'},
#   {'surface': 'に', 'base': 'に', 'pos': '助詞', 'pos1': '格助詞'},
#   {'surface': 'あがる', 'base': 'あがる', 'pos': '動詞', 'pos1': '自立'},
#   {'surface': '。', 'base': '。', 'pos': '記号', 'pos1': '句点'}],
#  [{'surface': '巨人', 'base': '巨人', 'pos': '名詞', 'pos1': '固有名詞'},
#   {'surface': '引力', 'base': '引力', 'pos': '名詞', 'pos1': '一般'},
#   {'surface': 'は', 'base': 'は', 'pos': '助詞', 'pos1': '係助詞'},
#   {'surface': '呼ぶ', 'base': '呼ぶ', 'pos': '動詞', 'pos1': '自立'},
#   {'surface': '。', 'base': '。', 'pos': '記号', 'pos1': '句点'}],
#  [{'surface': '呼ぶ', 'base': '呼ぶ', 'pos': '動詞', 'pos1': '自立'},
#   {'surface': 'と', 'base': 'と', 'pos': '助詞', 'pos1': '格助詞'},
#   {'surface': '落ち', 'base': '落ちる', 'pos': '動詞', 'pos1': '自立'},
#   {'surface': 'て', 'base': 'て', 'pos': '助詞', 'pos1': '接続助詞'},
#   {'surface': 'くる', 'base': 'くる', 'pos': '動詞', 'pos1': '非自立'},
#   {'surface': '」', 'base': '」', 'pos': '記号', 'pos1': '括弧閉'}],
#  [{'surface': '「', 'base': '「', 'pos': '記号', 'pos1': '括弧開'},
#   {'surface': 'それ', 'base': 'それ', 'pos': '名詞', 'pos1': '代名詞'},
#   {'surface': 'ぎりかい', 'base': '*', 'pos': '名詞', 'pos1': '一般'},
#   {'surface': '」', 'base': '」', 'pos': '記号', 'pos1': '括弧閉'},
#   {'surface': '「', 'base': '「', 'pos': '記号', 'pos1': '括弧開'},
#   {'surface': 'むむ', 'base': '*', 'pos': '名詞', 'pos1': '一般'},
#   {'surface': '、', 'base': '、', 'pos': '記号', 'pos1': '読点'},
#   {'surface': '甘い', 'base': '甘い', 'pos': '形容詞', 'pos1': '自立'},
#   {'surface': 'じゃ', 'base': 'じゃ', 'pos': '助詞', 'pos1': '副助詞'},
#   {'surface': 'ない', 'base': 'ない', 'pos': '助動詞', 'pos1': '*'},
#   {'surface': 'か', 'base': 'か', 'pos': '助詞', 'pos1': '副助詞／並立助詞／終助詞'},
#   {'surface': '」', 'base': '」', 'pos': '記号', 'pos1': '括弧閉'},
#   {'surface': '「', 'base': '「', 'pos': '記号', 'pos1': '括弧開'},
#   {'surface': 'いや', 'base': 'いや', 'pos': '接続詞', 'pos1': '*'},
#   {'surface': 'これ', 'base': 'これ', 'pos': '名詞', 'pos1': '代名詞'},
#   {'surface': 'は', 'base': 'は', 'pos': '助詞', 'pos1': '係助詞'},
#   {'surface': '恐れ入っ', 'base': '恐れ入る', 'pos': '動詞', 'pos1': '自立'},
#   {'surface': 'た', 'base': 'た', 'pos': '助動詞', 'pos1': '*'},
#   {'surface': '。', 'base': '。', 'pos': '記号', 'pos1': '句点'}],
#  [{'surface': '飛ん', 'base': '飛ぶ', 'pos': '動詞', 'pos1': '自立'},
#   {'surface': 'だ', 'base': 'だ', 'pos': '助動詞', 'pos1': '*'},
#   {'surface': 'ところ', 'base': 'ところ', 'pos': '名詞', 'pos1': '非自立'},
#   {'surface': 'で', 'base': 'で', 'pos': '助詞', 'pos1': '格助詞'},
#   {'surface': 'トチメンボー', 'base': '*', 'pos': '名詞', 'pos1': '一般'},
#   {'surface': 'の', 'base': 'の', 'pos': '助詞', 'pos1': '連体化'},
#   {'surface': '御', 'base': '御', 'pos': '接頭詞', 'pos1': '名詞接続'},
#   {'surface': '返礼', 'base': '返礼', 'pos': '名詞', 'pos1': 'サ変接続'},
#   {'surface': 'に', 'base': 'に', 'pos': '助詞', 'pos1': '格助詞'},
#   {'surface': '預っ', 'base': '預る', 'pos': '動詞', 'pos1': '自立'},
#   {'surface': 'た', 'base': 'た', 'pos': '助動詞', 'pos1': '*'},
#   {'surface': '」', 'base': '」', 'pos': '記号', 'pos1': '括弧閉'},
#   {'surface': '「', 'base': '「', 'pos': '記号', 'pos1': '括弧開'},
#   {'surface': '御', 'base': '御', 'pos': '接頭詞', 'pos1': '名詞接続'},
#   {'surface': '返礼', 'base': '返礼', 'pos': '名詞', 'pos1': 'サ変接続'},
#   {'surface': 'で', 'base': 'で', 'pos': '助詞', 'pos1': '格助詞'},
#   {'surface': 'も', 'base': 'も', 'pos': '助詞', 'pos1': '係助詞'},
#   {'surface': 'なん', 'base': 'なん', 'pos': '名詞', 'pos1': '代名詞'},
#   {'surface': 'で', 'base': 'で', 'pos': '助詞', 'pos1': '格助詞'},
#   {'surface': 'も', 'base': 'も', 'pos': '助詞', 'pos1': '係助詞'},
#   {'surface': 'ない', 'base': 'ない', 'pos': '形容詞', 'pos1': '自立'},
#   {'surface': 'さ', 'base': 'さ', 'pos': '助詞', 'pos1': '終助詞'},
#   {'surface': '、', 'base': '、', 'pos': '記号', 'pos1': '読点'},
#   {'surface': '実際', 'base': '実際', 'pos': '副詞', 'pos1': '助詞類接続'},
#   {'surface': 'うまい', 'base': 'うまい', 'pos': '形容詞', 'pos1': '自立'},
#   {'surface': 'から', 'base': 'から', 'pos': '助詞', 'pos1': '接続助詞'},
#   {'surface': '訳し', 'base': '訳す', 'pos': '動詞', 'pos1': '自立'},
#   {'surface': 'て', 'base': 'て', 'pos': '助詞', 'pos1': '接続助詞'},
#   {'surface': '見', 'base': '見る', 'pos': '動詞', 'pos1': '自立'},
#   {'surface': 'た', 'base': 'た', 'pos': '助動詞', 'pos1': '*'},
#   {'surface': 'の', 'base': 'の', 'pos': '名詞', 'pos1': '非自立'},
#   {'surface': 'さ', 'base': 'さ', 'pos': '助詞', 'pos1': '終助詞'},
#   {'surface': '、', 'base': '、', 'pos': '記号', 'pos1': '読点'},
#   {'surface': '君', 'base': '君', 'pos': '名詞', 'pos1': '代名詞'},
#   {'surface': 'は', 'base': 'は', 'pos': '助詞', 'pos1': '係助詞'},
#   {'surface': 'そう', 'base': 'そう', 'pos': '副詞', 'pos1': '助詞類接続'},
#   {'surface': '思わ', 'base': '思う', 'pos': '動詞', 'pos1': '自立'},
#   {'surface': 'ん', 'base': 'ん', 'pos': '助動詞', 'pos1': '*'},
#   {'surface': 'か', 'base': 'か', 'pos': '助詞', 'pos1': '副助詞／並立助詞／終助詞'},
#   {'surface': 'ね', 'base': 'ね', 'pos': '助詞', 'pos1': '終助詞'},
#   {'surface': '」', 'base': '」', 'pos': '記号', 'pos1': '括弧閉'},
#   {'surface': 'と', 'base': 'と', 'pos': '助詞', 'pos1': '格助詞'},
#   {'surface': '金縁', 'base': '金縁', 'pos': '名詞', 'pos1': '一般'},
#   {'surface': 'の', 'base': 'の', 'pos': '助詞', 'pos1': '連体化'},
#   {'surface': '眼鏡', 'base': '眼鏡', 'pos': '名詞', 'pos1': '一般'},
#   {'surface': 'の', 'base': 'の', 'pos': '助詞', 'pos1': '連体化'},
#   {'surface': '奥', 'base': '奥', 'pos': '名詞', 'pos1': '一般'},
#   {'surface': 'を', 'base': 'を', 'pos': '助詞', 'pos1': '格助詞'},
#   {'surface': '見る', 'base': '見る', 'pos': '動詞', 'pos1': '自立'},
#   {'surface': '。', 'base': '。', 'pos': '記号', 'pos1': '句点'}],
#  [{'surface': '「', 'base': '「', 'pos': '記号', 'pos1': '括弧開'},
#   {'surface': 'どうも', 'base': 'どうも', 'pos': '副詞', 'pos1': '一般'},
#   {'surface': '驚', 'base': '驚', 'pos': '名詞', 'pos1': '固有名詞'},
#   {'surface': 'ろ', 'base': 'ろ', 'pos': '名詞', 'pos1': '一般'},
#   {'surface': 'い', 'base': 'いる', 'pos': '動詞', 'pos1': '自立'},
#   {'surface': 'た', 'base': 'た', 'pos': '助動詞', 'pos1': '*'},
#   {'surface': 'ね', 'base': 'ね', 'pos': '助詞', 'pos1': '終助詞'},
#   {'surface': '。', 'base': '。', 'pos': '記号', 'pos1': '句点'}],
#  [{'surface': '君', 'base': '君', 'pos': '名詞', 'pos1': '代名詞'},
#   {'surface': 'に', 'base': 'に', 'pos': '助詞', 'pos1': '格助詞'},
#   {'surface': 'し', 'base': 'する', 'pos': '動詞', 'pos1': '自立'},
#   {'surface': 'て', 'base': 'て', 'pos': '助詞', 'pos1': '接続助詞'},
#   {'surface': 'この', 'base': 'この', 'pos': '連体詞', 'pos1': '*'},
#   {'surface': '伎倆', 'base': '伎倆', 'pos': '名詞', 'pos1': '一般'},
#   {'surface': 'あら', 'base': 'ある', 'pos': '動詞', 'pos1': '自立'},
#   {'surface': 'ん', 'base': 'ん', 'pos': '助動詞', 'pos1': '*'},
#   {'surface': 'と', 'base': 'と', 'pos': '助詞', 'pos1': '格助詞'},
#   {'surface': 'は', 'base': 'は', 'pos': '助詞', 'pos1': '係助詞'},
#   {'surface': '、', 'base': '、', 'pos': '記号', 'pos1': '読点'},
#   {'surface': '全く', 'base': '全く', 'pos': '副詞', 'pos1': '助詞類接続'},
#   {'surface': '此度', 'base': '*', 'pos': '名詞', 'pos1': '固有名詞'},
#   {'surface': 'という', 'base': 'という', 'pos': '助詞', 'pos1': '格助詞'},
#   {'surface': '今度', 'base': '今度', 'pos': '名詞', 'pos1': '副詞可能'},
#   {'surface': 'は', 'base': 'は', 'pos': '助詞', 'pos1': '係助詞'},
#   {'surface': '担が', 'base': '担ぐ', 'pos': '動詞', 'pos1': '自立'},
#   {'surface': 'れ', 'base': 'れる', 'pos': '動詞', 'pos1': '接尾'},
#   {'surface': 'た', 'base': 'た', 'pos': '助動詞', 'pos1': '*'},
#   {'surface': 'よ', 'base': 'よ', 'pos': '助詞', 'pos1': '終助詞'},
#   {'surface': '、', 'base': '、', 'pos': '記号', 'pos1': '読点'},
#   {'surface': '降参', 'base': '降参', 'pos': '名詞', 'pos1': 'サ変接続'},
#   {'surface': '降参', 'base': '降参', 'pos': '名詞', 'pos1': 'サ変接続'},
#   {'surface': '」', 'base': '」', 'pos': '記号', 'pos1': '括弧閉'},
#   {'surface': 'と', 'base': 'と', 'pos': '助詞', 'pos1': '格助詞'},
#   {'surface': '一', 'base': '一', 'pos': '名詞', 'pos1': '数'},
#   {'surface': '人', 'base': '人', 'pos': '名詞', 'pos1': '接尾'},
#   {'surface': 'で', 'base': 'で', 'pos': '助詞', 'pos1': '格助詞'},
#   {'surface': '承知', 'base': '承知', 'pos': '名詞', 'pos1': 'サ変接続'},
#   {'surface': 'し', 'base': 'する', 'pos': '動詞', 'pos1': '自立'},
#   {'surface': 'て', 'base': 'て', 'pos': '助詞', 'pos1': '接続助詞'},
#   {'surface': '一', 'base': '一', 'pos': '名詞', 'pos1': '数'},
#   {'surface': '人', 'base': '人', 'pos': '名詞', 'pos1': '接尾'},
#   {'surface': 'で', 'base': 'で', 'pos': '助詞', 'pos1': '格助詞'},
#   {'surface': '喋', 'base': '喋', 'pos': '名詞', 'pos1': '一般'},
#   {'surface': '舌', 'base': '舌', 'pos': '名詞', 'pos1': '一般'},
#   {'surface': 'る', 'base': 'る', 'pos': '助動詞', 'pos1': '*'},
#   {'surface': '。', 'base': '。', 'pos': '記号', 'pos1': '句点'}],
#  ...]
